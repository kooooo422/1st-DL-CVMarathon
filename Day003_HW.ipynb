# %%
import xmltodict
with open("C:/Users/yee91/Downloads/F-D0047-067.xml","r",encoding="utf-8") as f:
    doc=dict(xmltodict.parse(f.read()))
    newDoc=doc["cwbopendata"]["dataset"]["locations"]["location"]
    i=0
    j=0
    while(True):
        try:
            print(newDoc[i]["locationName"],newDoc[i]["weatherElement"][0]["time"][0]["startTime"],newDoc[i]["weatherElement"][0]["time"][0]["elementValue"]["value"],"攝氏度")
            i=i+1    
        except:
            break
    print("共",i,"個區")
while(True):
    try:
        print(newDoc[0]["locationName"],newDoc[0]["weatherElement"][0]["time"][j]["startTime"],newDoc[0]["weatherElement"][0]["time"][j]["elementValue"]["value"],"攝氏度")
        j=j+1
    except:
        break
#print(doc)
# Out:
# 鹽埕區 2021-01-26T00:00:00+08:00 18 攝氏度
# 鼓山區 2021-01-26T00:00:00+08:00 18 攝氏度
# 左營區 2021-01-26T00:00:00+08:00 17 攝氏度
# 楠梓區 2021-01-26T00:00:00+08:00 17 攝氏度
# 三民區 2021-01-26T00:00:00+08:00 18 攝氏度
# 新興區 2021-01-26T00:00:00+08:00 19 攝氏度
# 前金區 2021-01-26T00:00:00+08:00 18 攝氏度
# 苓雅區 2021-01-26T00:00:00+08:00 19 攝氏度
# 前鎮區 2021-01-26T00:00:00+08:00 19 攝氏度
# 旗津區 2021-01-26T00:00:00+08:00 18 攝氏度
# 小港區 2021-01-26T00:00:00+08:00 18 攝氏度
# 鳳山區 2021-01-26T00:00:00+08:00 18 攝氏度
# 林園區 2021-01-26T00:00:00+08:00 19 攝氏度
# 大寮區 2021-01-26T00:00:00+08:00 18 攝氏度
# 大樹區 2021-01-26T00:00:00+08:00 16 攝氏度
# 大社區 2021-01-26T00:00:00+08:00 16 攝氏度
# 仁武區 2021-01-26T00:00:00+08:00 17 攝氏度
# 鳥松區 2021-01-26T00:00:00+08:00 18 攝氏度
# 岡山區 2021-01-26T00:00:00+08:00 16 攝氏度
# 橋頭區 2021-01-26T00:00:00+08:00 16 攝氏度
# 燕巢區 2021-01-26T00:00:00+08:00 16 攝氏度
# 田寮區 2021-01-26T00:00:00+08:00 15 攝氏度
# 阿蓮區 2021-01-26T00:00:00+08:00 15 攝氏度
# 路竹區 2021-01-26T00:00:00+08:00 16 攝氏度
# 湖內區 2021-01-26T00:00:00+08:00 16 攝氏度
# ...
